# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/jmdhanyakumar/task04/tfenv/lib/python3.10/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /Users/jmdhanyakumar/task04/tfenv/lib/python3.10/site-packages (from opencv-python) (1.26.4)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: /Users/jmdhanyakumar/task04/tfenv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import tensorflow as tf
import numpy as np
from IPython.display import display, clear_output
from PIL import Image

# LOAD MODEL
model = tf.keras.models.load_model(
    "/Users/jmdhanyakumar/Desktop/MPROJECT/models/tomato_disease_model.h5"
)

# CLASS NAMES
class_names = [
    "Bacterial_Spot",
    "Cercospora_leaf_mold",
    "Early_Blight",
    "Healthy",
    "Insect_Damage",
    "Late_Blight",
    "Leaf_Miner",
    "Leaf_Mold",
    "Spider_Mites",
    "Tomato_Leaf_Curl_Virus"
]

# START CAMERA
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    if not ret:
        break

    # RESIZE FOR MODEL
    img = cv2.resize(frame, (224,224))

    # PREPROCESS
    img_array = np.expand_dims(img, axis=0)

    # PREDICT
    prediction = model.predict(img_array, verbose=0)

    predicted_class = class_names[np.argmax(prediction)]

    confidence = np.max(prediction) * 100

    # DISPLAY TEXT
    text = f"{predicted_class} ({confidence:.2f}%)"

    cv2.putText(
        frame,
        text,
        (20,40),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0,255,0),
        2
    )

    # CONVERT IMAGE
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    img_pil = Image.fromarray(frame_rgb)

    # SHOW FRAME
    clear_output(wait=True)
    display(img_pil)

    # PRESS CTRL+C IN NOTEBOOK TO STOP
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 43
#      40 img_array = np.expand_dims(img, axis=0)
#      42 # PREDICT
# ---> 43 prediction = model.predict(img_array, verbose=0)
#      45 predicted_class = class_names[np.argmax(prediction)]
#      47 confidence = np.max(prediction) * 100
#
# File ~/task04/tfenv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/task04/tfenv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:585, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     583 outputs = None
#     584 with epoch_iterator.catch_stop_iteration():
# --> 585     for begin_step, end_step, iterator in epoch_iterator:
#     586         callbacks.on_predict_batch_begin(begin_step)
#     587         data = get_data(iterator)
#
# File ~/task04/tfenv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:764, in TFEpochIterator.__next__(self)
#     763 def __next__(self):
# --> 764     return next(self._epoch_iterator)
#
# File ~/task04/tfenv/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:111, in EpochIterator._enumerate_iterator(self)
#     109 if steps_per_epoch > 0:
#     110     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 111         self._current_iterator = iter(self._get_iterator())
#     112         self._steps_seen = 0
#     113     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~/task04/tfenv/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~/task04/tfenv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:705, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     701   if (components is not None or element_spec is not None):
#     702     raise ValueError(
#     703         "When `dataset` is provided, `element_spec` and `components` must "
#     704         "not be specified.")
# --> 705   self._create_iterator(dataset)
#     707 self._get_next_call_count = 0
#
# File ~/task04/tfenv/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:744, in OwnedIterator._create_iterator(self, dataset)
#     741   assert len(fulltype.args[0].args[0].args) == len(
#     742       self._flat_output_types)
#     743   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 744 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/task04/tfenv/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Out:
#   Cell In[6], line 1
#     python live_detection.py
#            ^
# SyntaxError: invalid syntax
